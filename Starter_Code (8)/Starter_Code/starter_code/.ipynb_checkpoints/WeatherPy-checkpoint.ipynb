# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 263

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=" + "Metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | besuki
# Processing Record 2 of Set 1 | nerchinsk
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | uppsala
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | monte azul
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | khorixas
# Processing Record 10 of Set 1 | rengasdengklok
# Processing Record 11 of Set 1 | phan rang-thap cham
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | college
# Processing Record 14 of Set 1 | puducherry
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | chonchi
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | camacupa
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | flying fish cove
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | gagnoa
# Processing Record 24 of Set 1 | dabhol
# Processing Record 25 of Set 1 | puerto natales
# Processing Record 26 of Set 1 | pathein
# Processing Record 27 of Set 1 | saint-denis
# Processing Record 28 of Set 1 | bilibino
# Processing Record 29 of Set 1 | obo
# Processing Record 30 of Set 1 | at taj
# Processing Record 31 of Set 1 | khash
# Processing Record 32 of Set 1 | cable beach
# City not found. Skipping...
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | enewetak
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | mudgee
# Processing Record 37 of Set 1 | la passe
# Processing Record 38 of Set 1 | wailua homesteads
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | boldumsaz
# Processing Record 41 of Set 1 | santa ana
# Processing Record 42 of Set 1 | hohhot
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | turkmenbasy
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | puerto baquerizo moreno
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | port douglas
# Processing Record 0 of Set 2 | bandarbeyla
# Processing Record 1 of Set 2 | haiku-pauwela
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | sao paulo de olivenca
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | ha'il
# Processing Record 6 of Set 2 | awjilah
# Processing Record 7 of Set 2 | yarmouth
# Processing Record 8 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 9 of Set 2 | antsohihy
# Processing Record 10 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 2 | nemuro
# Processing Record 12 of Set 2 | huaraz
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | kolonia town
# Processing Record 15 of Set 2 | waitangi
# Processing Record 16 of Set 2 | edinburgh of the seven seas
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | yeniseysk
# Processing Record 20 of Set 2 | quellon
# Processing Record 21 of Set 2 | pointe aux piments
# Processing Record 22 of Set 2 | vorkuta
# Processing Record 23 of Set 2 | nako
# Processing Record 24 of Set 2 | comodoro rivadavia
# Processing Record 25 of Set 2 | uturoa
# Processing Record 26 of Set 2 | basoko
# Processing Record 27 of Set 2 | kailua-kona
# Processing Record 28 of Set 2 | ola
# Processing Record 29 of Set 2 | nadi
# Processing Record 30 of Set 2 | pratt
# Processing Record 31 of Set 2 | kingston
# Processing Record 32 of Set 2 | vadso
# Processing Record 33 of Set 2 | whitehorse
# Processing Record 34 of Set 2 | nikol'sk
# Processing Record 35 of Set 2 | bcharre
# Processing Record 36 of Set 2 | arno
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | el calafate
# Processing Record 39 of Set 2 | papatowai
# Processing Record 40 of Set 2 | saipan
# Processing Record 41 of Set 2 | tralee
# Processing Record 42 of Set 2 | east london
# City not found. Skipping...
# Processing Record 43 of Set 2 | talcahuano
# Processing Record 44 of Set 2 | west island
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | lospalos
# Processing Record 47 of Set 2 | midleton
# Processing Record 48 of Set 2 | chokwe
# Processing Record 49 of Set 2 | suva
# Processing Record 0 of Set 3 | peshawar
# Processing Record 1 of Set 3 | oriximina
# Processing Record 2 of Set 3 | shibetsu
# Processing Record 3 of Set 3 | weno
# Processing Record 4 of Set 3 | stanley
# Processing Record 5 of Set 3 | hawaiian paradise park
# Processing Record 6 of Set 3 | margaret river
# Processing Record 7 of Set 3 | laguna
# Processing Record 8 of Set 3 | praia da vitoria
# Processing Record 9 of Set 3 | antofagasta
# Processing Record 10 of Set 3 | tugulym
# Processing Record 11 of Set 3 | aqaba
# Processing Record 12 of Set 3 | kapuskasing
# Processing Record 13 of Set 3 | minas de marcona
# Processing Record 14 of Set 3 | ar ruways
# Processing Record 15 of Set 3 | dauphin
# Processing Record 16 of Set 3 | olonkinbyen
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | santa cruz
# Processing Record 19 of Set 3 | gobabis
# Processing Record 20 of Set 3 | holdrege
# Processing Record 21 of Set 3 | chardara
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | vilyuchinsk
# Processing Record 24 of Set 3 | klyuchi
# Processing Record 25 of Set 3 | port saint john's
# Processing Record 26 of Set 3 | cole harbour
# Processing Record 27 of Set 3 | malindi
# Processing Record 28 of Set 3 | chagoda
# Processing Record 29 of Set 3 | nuku'alofa
# Processing Record 30 of Set 3 | poltavka
# Processing Record 31 of Set 3 | slave lake
# Processing Record 32 of Set 3 | al kharijah
# Processing Record 33 of Set 3 | usinsk
# Processing Record 34 of Set 3 | umarga
# Processing Record 35 of Set 3 | al ghayzah
# Processing Record 36 of Set 3 | twon-brass
# Processing Record 37 of Set 3 | kone
# Processing Record 38 of Set 3 | badger
# Processing Record 39 of Set 3 | the pas
# Processing Record 40 of Set 3 | egilsstadir
# Processing Record 41 of Set 3 | turpan
# Processing Record 42 of Set 3 | alice springs
# Processing Record 43 of Set 3 | zaozersk
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | karratha
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | hailar
# Processing Record 48 of Set 3 | thunder bay
# Processing Record 49 of Set 3 | kharp
# Processing Record 0 of Set 4 | razole
# Processing Record 1 of Set 4 | vilyuysk
# Processing Record 2 of Set 4 | labrador city
# Processing Record 3 of Set 4 | viedma
# Processing Record 4 of Set 4 | crane
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | dunedin
# Processing Record 7 of Set 4 | manavalakurichi
# Processing Record 8 of Set 4 | kladno
# Processing Record 9 of Set 4 | kourou
# Processing Record 10 of Set 4 | st. john's
# Processing Record 11 of Set 4 | daru
# Processing Record 12 of Set 4 | nar'yan-mar
# Processing Record 13 of Set 4 | udachny
# Processing Record 14 of Set 4 | makinsk
# Processing Record 15 of Set 4 | tazovsky
# Processing Record 16 of Set 4 | dudinka
# Processing Record 17 of Set 4 | auki
# Processing Record 18 of Set 4 | leava
# Processing Record 19 of Set 4 | lihue
# Processing Record 20 of Set 4 | laizhou
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | san agustin de valle fertil
# Processing Record 24 of Set 4 | howrah
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | gao
# Processing Record 27 of Set 4 | nha trang
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 30 of Set 4 | vikulovo
# Processing Record 31 of Set 4 | dwarka
# Processing Record 32 of Set 4 | briviesca
# Processing Record 33 of Set 4 | port kembla
# Processing Record 34 of Set 4 | nova sintra
# Processing Record 35 of Set 4 | sao jose da coroa grande
# Processing Record 36 of Set 4 | tughyl
# Processing Record 37 of Set 4 | greenville
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | kadisehri
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | yigo village
# Processing Record 42 of Set 4 | dayr al balah
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | isafjordur
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | antsiranana
# Processing Record 47 of Set 4 | iskateley
# Processing Record 48 of Set 4 | port mathurin
# Processing Record 49 of Set 4 | kuanda
# Processing Record 0 of Set 5 | jieshi
# Processing Record 1 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 5 | unai
# Processing Record 3 of Set 5 | skovorodino
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | lebyazh'ye
# Processing Record 6 of Set 5 | cangzhou
# Processing Record 7 of Set 5 | bissau
# Processing Record 8 of Set 5 | iwaki
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | naze
# Processing Record 11 of Set 5 | debre werk'
# Processing Record 12 of Set 5 | atafu village
# Processing Record 13 of Set 5 | sao gabriel da cachoeira
# Processing Record 14 of Set 5 | anadyr
# Processing Record 15 of Set 5 | qui nhon
# Processing Record 16 of Set 5 | plouzane
# Processing Record 17 of Set 5 | pechora
# Processing Record 18 of Set 5 | khandyga
# Processing Record 19 of Set 5 | utrik
# Processing Record 20 of Set 5 | al qusayr
# Processing Record 21 of Set 5 | itoman
# Processing Record 22 of Set 5 | invercargill
# Processing Record 23 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 24 of Set 5 | mount isa
# Processing Record 25 of Set 5 | aberdeen
# Processing Record 26 of Set 5 | tabou
# Processing Record 27 of Set 5 | qaqortoq
# Processing Record 28 of Set 5 | palikir - national government center
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | newman
# Processing Record 31 of Set 5 | chaihe
# Processing Record 32 of Set 5 | santiago de cao
# Processing Record 33 of Set 5 | makokou
# Processing Record 34 of Set 5 | sinabang
# Processing Record 35 of Set 5 | katsuren-haebaru
# Processing Record 36 of Set 5 | ust-tsilma
# Processing Record 37 of Set 5 | ust-nera
# Processing Record 38 of Set 5 | severo-yeniseyskiy
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | moose jaw
# Processing Record 41 of Set 5 | gilgit
# Processing Record 42 of Set 5 | wynyard
# Processing Record 43 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 44 of Set 5 | balaipungut
# Processing Record 45 of Set 5 | esmeraldas
# Processing Record 46 of Set 5 | dalnerechensk
# Processing Record 47 of Set 5 | pacific grove
# Processing Record 48 of Set 5 | plettenberg bay
# Processing Record 49 of Set 5 | kristiansund
# Processing Record 0 of Set 6 | laojunmiao
# Processing Record 1 of Set 6 | tyul'gan
# Processing Record 2 of Set 6 | ust'-talovka
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | jiuquan
# Processing Record 5 of Set 6 | andreyevo
# Processing Record 6 of Set 6 | oulmes
# Processing Record 7 of Set 6 | sofifi
# City not found. Skipping...
# Processing Record 8 of Set 6 | yerofey pavlovich
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | lata
# Processing Record 11 of Set 6 | mossel bay
# Processing Record 12 of Set 6 | london
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          254
# Lat           254
# Lng           254
# Max Temp      254
# Humidity      254
# Cloudiness    254
# Wind Speed    254
# Country       254
# Date          254
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             besuki  -7.7338  113.6979     28.63        71          92
# 1          nerchinsk  51.9833  116.5833     -8.55        81         100
# 2     cabo san lucas  22.8909 -109.9124     29.78        57         100
# 3            uppsala  60.0000   17.7500     -2.27       100         100
# 4  port-aux-francais -49.3500   70.2167      4.76        83          98
#
#    Wind Speed Country        Date
# 0        1.09      ID  1700092150
# 1        4.49      RU  1700092151
# 2        4.12      MX  1700091923
# 3        4.63      SE  1700092152
# 4       17.36      TF  1700092152

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   besuki  -7.7338  113.6979     28.63        71          92
# 1                nerchinsk  51.9833  116.5833     -8.55        81         100
# 2           cabo san lucas  22.8909 -109.9124     29.78        57         100
# 3                  uppsala  60.0000   17.7500     -2.27       100         100
# 4        port-aux-francais -49.3500   70.2167      4.76        83          98
#
#          Wind Speed Country        Date
# City_ID
# 0              1.09      ID  1700092150
# 1              4.49      RU  1700092151
# 2              4.12      MX  1700091923
# 3              4.63      SE  1700092152
# 4             17.36      TF  1700092152

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Lat vs Temp")
plt.xlabel("Latitude")
plt.ylabel("Temp")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Lat vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Lat vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("City Lat vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_lin_regression(x_values, y_values, ylabel, text_coords):
    
    (slope, intercept, rvalue, pvalue, sterr) = linregress(x_values, y_values)
    y_hat = x_values*slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, y_hat, "r-")
    plt.annotate(line_eq, text_coords, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                  nerchinsk  51.9833  116.5833     -8.55        81
# 2             cabo san lucas  22.8909 -109.9124     29.78        57
# 3                    uppsala  60.0000   17.7500     -2.27       100
# 10       phan rang-thap cham  11.5667  108.9833     25.78        88
# 11                    albany  42.6001  -73.9662      8.23        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1               100        4.49      RU  1700092151
# 2               100        4.12      MX  1700091923
# 3               100        4.63      SE  1700092152
# 10               92        3.56      VN  1700092156
# 11               97        1.27      US  1700092157

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   besuki  -7.7338  113.6979     28.63        71          92
# 4        port-aux-francais -49.3500   70.2167      4.76        83          98
# 5               bredasdorp -34.5322   20.0403     18.45        82         100
# 6               monte azul -15.1550  -42.8747     27.46        40          46
# 7            blackmans bay -43.0167  147.3167     12.63        62         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.09      ID  1700092150
# 4             17.36      TF  1700092152
# 5              0.45      ZA  1700092153
# 6              2.09      BR  1700092153
# 7              0.89      AU  1700092154

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_lin_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Max Temp", (6,-10))
# Out:
# The r-value is: 0.7900635059041379

# %%
# Linear regression on Southern Hemisphere
plot_lin_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Max Temp", (6,-10))
# Out:
# The r-value is: 0.613118534294825

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Humidity", (6,-10))
# Out:
# The r-value is: 0.02236487103422248

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Humidity", (6,-10))
# Out:
# The r-value is: 0.058843926979231055

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Cloudiness", (6,-10))
# Out:
# The r-value is: 0.014812025785873989

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Cloudiness", (6,-10))
# Out:
# The r-value is: 0.012384419269310165

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_lin_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Wind Speed", (6,-10))
# Out:
# The r-value is: 0.008113675625862493

# %%
# Southern Hemisphere
plot_lin_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Wind Speed", (6,-10))
# Out:
# The r-value is: 0.08952309534354223

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
